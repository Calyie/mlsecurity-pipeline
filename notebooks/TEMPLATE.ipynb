# %% [markdown]
# # <Experiment title>
#
# **Question.** One sentence: what this notebook finds out. Example: how much accuracy does a CNN
# lose on clean MNIST digits as an attacker flips a growing share of its training labels?
#
# **Threat model.**
# - Attacker's goal: (evasion / poisoning / extraction / membership inference)
# - Attacker's access: (training data? model weights? queries only? how many?)
# - Attacker's knowledge: (architecture, training set, nothing)
# - Victim's defence, if any:
#
# **Setup.** Dataset, model, split, seed, hardware. Everything a reader needs to rerun it.

# %%
import sys; sys.path.insert(0, "..")      # so `pipeline` imports from the repo root
import numpy as np
import torch
from pipeline import SEED, log_result, load_results

torch.manual_seed(SEED); np.random.seed(SEED)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
EXPERIMENT = "<short_name>"                 # the name rows are logged under
print("device:", DEVICE)

# %% [markdown]
# ## 1. Data
#
# Load the data and show its shape and class balance. State what is train, what is test, and what the attacker sees.

# %%
# load the data here

# %% [markdown]
# ## 2. Baseline
#
# Train the clean model and measure it on the clean test set. This is the number every attack is compared against.

# %%
# train and evaluate the baseline here
baseline_accuracy = None

# %% [markdown]
# ## 3. Attack
#
# One attack, one parameter swept (poison rate, epsilon, number of queries, ...). Show one example of what the attack produces.

# %%
# run the attack across the sweep here; log every point
# log_result(EXPERIMENT, condition="attack", parameter=..., accuracy=...)

# %% [markdown]
# ## 4. Defence
#
# One defence, measured on the same sweep. Say what it costs on clean accuracy.

# %%
# run the defence here; log every point

# %% [markdown]
# ## 5. Results
#
# One table: rows are the sweep, columns are baseline, attack, defence. One figure if it helps.

# %%
load_results(EXPERIMENT)

# %% [markdown]
# ## 6. What this shows, and what it does not
#
# - Shows:
# - Does not show: (single seed, one dataset, one architecture, attacker assumptions ...)
# - What would change the conclusion:
#
# ## References
#
# - Paper or article the attack comes from.
